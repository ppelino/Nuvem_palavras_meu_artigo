# %%
pip install nltk wordcloud
# Out:
# Requirement already satisfied: nltk in c:\users\ppeli\anaconda3.11\lib\site-packages (3.7)
# Requirement already satisfied: wordcloud in c:\users\ppeli\anaconda3.11\lib\site-packages (1.9.1.1)
# Requirement already satisfied: tqdm in c:\users\ppeli\anaconda3.11\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in c:\users\ppeli\anaconda3.11\lib\site-packages (from nltk) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ppeli\anaconda3.11\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: click in c:\users\ppeli\anaconda3.11\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: pillow in c:\users\ppeli\anaconda3.11\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\ppeli\anaconda3.11\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ppeli\anaconda3.11\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: colorama in c:\users\ppeli\appdata\roaming\python\python310\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\ppeli\anaconda3.11\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ppeli\anaconda3.11\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ppeli\anaconda3.11\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ppeli\anaconda3.11\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ppeli\anaconda3.11\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ppeli\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ppeli\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: six>=1.5 in c:\users\ppeli\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)

# %%
pip install PDFReader
# Out:
# Collecting PDFReaderNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pdfreader-0.1.12.tar.gz (2.9 MB)
#      ---------------------------------------- 2.9/2.9 MB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting bitarray>=1.1.0
#   Downloading bitarray-2.8.2-cp310-cp310-win_amd64.whl (122 kB)
#      -------------------------------------- 122.7/122.7 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=7.1.0 in c:\users\ppeli\anaconda3.11\lib\site-packages (from PDFReader) (9.4.0)
# Collecting pycryptodome>=3.9.9
#   Downloading pycryptodome-3.19.0-cp35-abi3-win_amd64.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ppeli\appdata\roaming\python\python310\site-packages (from PDFReader) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ppeli\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.1->PDFReader) (1.16.0)
# Building wheels for collected packages: PDFReader
#   Building wheel for PDFReader (setup.py): started
#   Building wheel for PDFReader (setup.py): finished with status 'done'
#   Created wheel for PDFReader: filename=pdfreader-0.1.12-py3-none-any.whl size=134571 sha256=af1d4f6d248578cb1fa68fb53a525e1cbf1e0ab2d229e2da4dee9d13675efb4c
#   Stored in directory: c:\users\ppeli\appdata\local\pip\cache\wheels\d9\65\06\024971eab3d7d78cab2aa9a7f54bc866aeaf76b081baaeff45
# Successfully built PDFReader
# Installing collected packages: bitarray, pycryptodome, PDFReader
# Successfully installed PDFReader-0.1.12 bitarray-2.8.2 pycryptodome-3.19.0
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ppeli\anaconda3.11\lib\site-packages)

# %%
import PyPDF2

pdf_file = open('Template_TCC (1).pdf', 'rb')
pdf_reader = PyPDF2.PdfReader(pdf_file)

text = ''
for page_num in range(len(pdf_reader.pages)):
    page = pdf_reader.pages[page_num]
    text += page.extract_text()

pdf_file.close()

# %%
# Limpeza de texto
def clean_text(text):
    stop_words = set(stopwords.words('portuguese'))
    text = text.lower()
    text = ''.join([char for char in text if char not in string.punctuation])
    text = ' '.join([word for word in text.split() if word not in stop_words])
    return text

cleaned_text = clean_text(text)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(cleaned_text)

# Exibir a nuvem de palavras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
